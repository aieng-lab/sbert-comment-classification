# %% [markdown]
# **Goal:** Analyze the second part of the results of the second experimentation stage (optimization of classification heads).

# %%
import json
import math
import os

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
COMPETITION_PATH = "../competition_s2/{}"

MODEL_ALIASES = {
    "paraphrase-MiniLM-L3-v2": "pml3",
    "all-mpnet-base-v2": "amb",
    "all-MiniLM-L6-v2": "aml6",
    "paraphrase-albert-small-v2": "pas",
    "all-distilroberta-v1": "adr",
    "baseline_opt": "baseline.json",  # Baseline model WITH optimization
    "baseline_org": "nlbse25.json"  # Baseline model WITHOUT optimization 
}

aliases = {v: k for k, v in MODEL_ALIASES.items()}

# %%
langs = ["java", "python", "pharo"]

# %%
results = []

for lang in langs:
    competition_path = COMPETITION_PATH.format(lang)
    for file_name in os.listdir(competition_path):
        if file_name.endswith(".json"):
            file_path = os.path.join(competition_path, file_name)
            with open(file_path, "r") as json_file:
                try:
                    data = json.load(json_file)
                    data["language"] = lang
                    data["experiment"] = file_name 

                    # Remove references to language
                    data = {key.removeprefix(f"{lang}_"): value for key, value in data.items()}

                    results.append(data)
                except json.JSONDecodeError as e:
                    print(f"Error decoding JSON from file {file_name}: {e}")

# %%
results_df = pd.DataFrame(results)
results_df["model"] = results_df["experiment"].apply(lambda x: aliases[x.split("-")[0]])

def fff(row):
    if isinstance(row["head"], float):
        return "default"
    
    alg = row["head"]["algorithm"].upper()
    if not row["head"]["hparams"] is None:
        hparams = ", ".join([f"{k}: {v}" for k, v in row["head"]["hparams"].items()])
        return f"{alg}, {hparams}"
    else:
        return "default"

results_df["head"] = results_df.apply(fff, axis=1)

# %%
max_avg_runtime = 5
max_avg_flops = 5000

# Calculate submission score
results_df["avg_f1_w"] = 0.6 * results_df["avg_f1"]
results_df["avg_runtime_w"] = 0.2 * (max_avg_runtime - results_df["avg_runtime"]) / max_avg_runtime
results_df["avg_flops_w"] = 0.2 * (max_avg_flops - results_df["avg_flops"]) / max_avg_flops
results_df["submission_score"] = results_df["avg_f1_w"] + results_df["avg_runtime_w"] + results_df["avg_flops_w"]

# %%
results_df[["language", "model", "head", "avg_f1", "avg_runtime", "avg_flops", "submission_score"]]
# Out:
#    language                       model                          head  \
# 0      java     paraphrase-MiniLM-L3-v2                   LR, C: 0.01
# 1      java            all-MiniLM-L6-v2              RF, max_depth: 9
# 2      java  paraphrase-albert-small-v2     SVM, C: 0.01, kernel: rbf
# 3      java                baseline_opt  SVM, C: 0.01, kernel: linear
# 4      java                baseline_org                       default
# 5      java        all-distilroberta-v1   SVM, C: 0.1, kernel: linear
# 6      java           all-mpnet-base-v2     SVM, C: 0.01, kernel: rbf
# 7    python     paraphrase-MiniLM-L3-v2                    LR, C: 0.1
# 8    python  paraphrase-albert-small-v2                   LR, C: 0.01
# 9    python            all-MiniLM-L6-v2              RF, max_depth: 4
# 10   python                baseline_org                       default
# 11   python           all-mpnet-base-v2              XG, max_depth: 2
# 12   python                baseline_opt                   LR, C: 0.01
# 13   python        all-distilroberta-v1              RF, max_depth: 6
# 14    pharo        all-distilroberta-v1              RF, max_depth: 6
# 15    pharo                baseline_opt              RF, max_depth: 5
# 16    pharo           all-mpnet-base-v2                       default
# 17    pharo     paraphrase-MiniLM-L3-v2     SVM, C: 1.0, kernel: poly
# 18    pharo                baseline_org                       default
# 19    pharo            all-MiniLM-L6-v2              RF, max_depth: 6
# 20    pharo  paraphrase-albert-small-v2  SVM, C: 1.0, kernel: sigmoid
#
#       avg_f1  avg_runtime     avg_flops  submission_score
# 0   0.711885     2.114411    803.469045          0.710416
# 1   0.725131     0.912680   1782.400462          0.727276
# 2   0.727682     3.257322   6375.593890          0.451293
# 3   0.702185     2.169038    803.469045          0.702411
# 4   0.697896     0.674966    803.469045          0.759600
# 5   0.737756     2.684387   7527.899191          0.434162
# 6   0.740374     3.704301  15342.338443          0.082359
# 7   0.616481     1.558289    103.621319          0.703412
# 8   0.615693     1.804605    966.818870          0.658559
# 9   0.656355     0.321210    207.115418          0.772680
# 10  0.603018     0.235084    103.621319          0.748263
# 11  0.654782     0.364752   1665.658664          0.711653
# 12  0.606248     1.566977    103.621319          0.696925
# 13  0.673748     0.344741    811.953862          0.757981
# 14  0.665834     0.301402    658.051819          0.761123
# 15  0.635550     0.239418     91.936779          0.768076
# 16  0.710518     0.329635   1481.310230          0.753873
# 17  0.641445     1.586036     91.936779          0.717748
# 18  0.606793     0.197318     91.936779          0.752505
# 19  0.636465     0.283762    183.781687          0.763177
# 20  0.657931     1.654116    746.090307          0.698750
